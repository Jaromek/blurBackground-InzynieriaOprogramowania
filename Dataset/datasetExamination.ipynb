# %% [markdown]
# # ALL IMPORTS

# %%
from PIL import Image
import os
from icecream import ic
from collections import Counter

# %% [markdown]
# # PATHS TO DATASET

# %%
PATH_IMAGES = "humanSegmentation/images"

# %% [markdown]
# # CHECK EVERY IMAGE SIZE AND PRINT DIFFERENT SIZES AND ITS COUNT

# %%
images = os.listdir(PATH_IMAGES)
sizes = [Image.open(os.path.join(PATH_IMAGES, img)).size for img in images]
size_dict = Counter(sizes)

# %%
ic(list(size_dict.keys())[:3])
ic(len(size_dict))
# Out:
# ic| list(size_dict.keys())[:10]: [(532, 800),
#                                   (800, 800),
#                                   (533, 800),
#                                   (4019, 2679),
#                                   (1200, 800),
#                                   (1067, 800),
#                                   (1261, 800),
#                                   (944, 800),
#                                   (623, 800),
#                                   (1252, 800)]
# ic| len(size_dict): 489
# 489

# %% [markdown]
# # 489 different image sizes
